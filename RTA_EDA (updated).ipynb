# %% [markdown]
# ## Summary (this section can be updated)
# What is done:
# - checked for missing values and duplicates
# - converted time to datetime type and floored to every half an hour
# - reduced number of unique values for different columns (not done completely)

# %% [markdown]
# ### Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from datetime import datetime
import plotly.express as px
# !pip -q install phik
from phik.report import plot_correlation_matrix
from phik import report
import seaborn as sns
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 5.4 MB/s eta 0:00:00

# %%
url = 'https://drive.google.com/file/d/1ScumN0PnQDPMl_ElMCySKOg2syceIkZW/view?usp=sharing'
url ='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
df.head()
# Out:
#        time day_of_week age_band_of_driver sex_of_driver   educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3  01:06:00      Sunday              18-30          Male  Junior high school
# 4  01:06:00      Sunday              18-30          Male  Junior high school
#
#   vehicle_driver_relation driving_experience      type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr           Automobile
#
#   owner_of_vehicle service_year_of_vehicle  ...  vehicle_movement  \
# 0            Owner              Above 10yr  ...    Going straight
# 1            Owner                 5-10yrs  ...    Going straight
# 2            Owner                 Unknown  ...    Going straight
# 3     Governmental                 Unknown  ...    Going straight
# 4            Owner                 5-10yrs  ...    Going straight
#
#     casualty_class sex_of_casualty age_band_of_casualty casualty_severity  \
# 0          Unknown         Unknown              Unknown                 0
# 1          Unknown         Unknown              Unknown                 0
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4          Unknown         Unknown              Unknown                 0
#
#   work_of_casualty fitness_of_casualty pedestrian_movement  \
# 0          Unknown               Other    Not a Pedestrian
# 1          Unknown               Other    Not a Pedestrian
# 2           Driver               Other    Not a Pedestrian
# 3           Driver              Normal    Not a Pedestrian
# 4          Unknown               Other    Not a Pedestrian
#
#             cause_of_accident accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Data integrity

# %%
df.columns
# Out:
# Index(['time', 'day_of_week', 'age_band_of_driver', 'sex_of_driver',
#        'educational_level', 'vehicle_driver_relation', 'driving_experience',
#        'type_of_vehicle', 'owner_of_vehicle', 'service_year_of_vehicle',
#        'defect_of_vehicle', 'area_accident_occured', 'lanes_or_medians',
#        'road_allignment', 'types_of_junction', 'road_surface_type',
#        'road_surface_conditions', 'light_conditions', 'weather_conditions',
#        'type_of_collision', 'number_of_vehicles_involved',
#        'number_of_casualties', 'vehicle_movement', 'casualty_class',
#        'sex_of_casualty', 'age_band_of_casualty', 'casualty_severity',
#        'work_of_casualty', 'fitness_of_casualty', 'pedestrian_movement',
#        'cause_of_accident', 'accident_severity'],
#       dtype='object')

# %% [markdown]
# Checking for dtypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   time                         12316 non-null  object
#  1   day_of_week                  12316 non-null  object
#  2   age_band_of_driver           12316 non-null  object
#  3   sex_of_driver                12316 non-null  object
#  4   educational_level            12316 non-null  object
#  5   vehicle_driver_relation      12316 non-null  object
#  6   driving_experience           12316 non-null  object
#  7   type_of_vehicle              12316 non-null  object
#  8   owner_of_vehicle             12316 non-null  object
#  9   service_year_of_vehicle      12316 non-null  object
#  10  defect_of_vehicle            12316 non-null  int64
#  11  area_accident_occured        12316 non-null  object
#  12  lanes_or_medians             12316 non-null  object
#  13  road_allignment              12316 non-null  object
#  14  types_of_junction            12316 non-null  object
#  15  road_surface_type            12316 non-null  object
#  16  road_surface_conditions      12316 non-null  object
#  17  light_conditions             12316 non-null  object
#  18  weather_conditions           12316 non-null  object
#  19  type_of_collision            12316 non-null  object
#  20  number_of_vehicles_involved  12316 non-null  int64
#  21  number_of_casualties         12316 non-null  int64
#  22  vehicle_movement             12316 non-null  object
#  23  casualty_class               12316 non-null  object
#  24  sex_of_casualty              12316 non-null  object
#  25  age_band_of_casualty         12316 non-null  object
#  26  casualty_severity            12316 non-null  int64
#  27  work_of_casualty             12316 non-null  object
#  28  fitness_of_casualty          12316 non-null  object
#  29  pedestrian_movement          12316 non-null  object
#  30  cause_of_accident            12316 non-null  object
#  31  accident_severity            12316 non-null  object
# dtypes: int64(4), object(28)
# memory usage: 3.0+ MB

# %% [markdown]
# Checking for missing values and duplicates

# %%
print(df.duplicated().sum())
print(df.isna().sum().sum())
# Out:
# 0
# 0

# %% [markdown]
# Here we can inspect column for unique values, and also sort them by it's amount.

# %%
for column_name in df.columns:
    print(f'Column name: {column_name}, number of unique values: {df[column_name].nunique()}')
    print(df[column_name].value_counts())
    print('-----------')
# Out:
# Column name: time, number of unique values: 1074
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 19:04:00      1
# 20:36:00      1
# 22:54:00      1
# 21:03:00      1
# 02:47:00      1
# Name: time, Length: 1074, dtype: int64
# -----------
# Column name: day_of_week, number of unique values: 7
# Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# Saturday     1666
# Sunday       1467
# Name: day_of_week, dtype: int64
# -----------
# Column name: age_band_of_driver, number of unique values: 5
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: age_band_of_driver, dtype: int64
# -----------
# Column name: sex_of_driver, number of unique values: 3
# Male       11437
# Female       701
# Unknown      178
# Name: sex_of_driver, dtype: int64
# -----------
# Column name: educational_level, number of unique values: 7
# Junior high school    8360
# Elementary school     2163
# High school           1110
# Above high school      362
# Writing & reading      176
# Unknown                100
# Illiterate              45
# Name: educational_level, dtype: int64
# -----------
# Column name: vehicle_driver_relation, number of unique values: 4
# Employee    10206
# Owner        1973
# Other         123
# Unknown        14
# Name: vehicle_driver_relation, dtype: int64
# -----------
# Column name: driving_experience, number of unique values: 7
# 5-10yr        4192
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# No Licence     118
# unknown         33
# Name: driving_experience, dtype: int64
# -----------
# Column name: type_of_vehicle, number of unique values: 17
# Automobile              4155
# Lorry (41?100Q)         2186
# Other                   1208
# Pick up upto 10Q         811
# Public (12 seats)        711
# Stationwagen             687
# Lorry (11?40Q)           541
# Public (13?45 seats)     532
# Public (> 45 seats)      404
# Long lorry               383
# Taxi                     265
# Motorcycle               177
# Special vehicle           84
# Ridden horse              76
# Turbo                     46
# Bajaj                     29
# Bicycle                   21
# Name: type_of_vehicle, dtype: int64
# -----------
# Column name: owner_of_vehicle, number of unique values: 4
# Owner           10941
# Governmental     1041
# Organization      312
# Other              22
# Name: owner_of_vehicle, dtype: int64
# -----------
# Column name: service_year_of_vehicle, number of unique values: 6
# Unknown       6811
# 2-5yrs        1792
# Above 10yr    1324
# 5-10yrs       1280
# 1-2yr          827
# Below 1yr      282
# Name: service_year_of_vehicle, dtype: int64
# -----------
# Column name: defect_of_vehicle, number of unique values: 3
# 0    12204
# 7       76
# 5       36
# Name: defect_of_vehicle, dtype: int64
# -----------
# Column name: area_accident_occured, number of unique values: 14
# Other                              4058
# Office areas                       3451
# Residential areas                  2060
#  Church areas                      1060
#  Industrial areas                   456
# School areas                        415
#   Recreational areas                327
#  Outside rural areas                218
#  Hospital areas                     121
#   Market areas                       63
# Rural village areas                  44
# Unknown                              22
# Rural village areasOffice areas      20
# Recreational areas                    1
# Name: area_accident_occured, dtype: int64
# -----------
# Column name: lanes_or_medians, number of unique values: 7
# Two-way (divided with broken lines road marking)    4796
# Undivided Two way                                   3796
# other                                               1660
# Double carriageway (median)                         1020
# One way                                              845
# Two-way (divided with solid lines road marking)      142
# Unknown                                               57
# Name: lanes_or_medians, dtype: int64
# -----------
# Column name: road_allignment, number of unique values: 9
# Tangent road with flat terrain                   10601
# Tangent road with mild grade and flat terrain      501
# Steep grade downward with mountainous terrain      429
# Tangent road with mountainous terrain and          396
# Gentle horizontal curve                            163
# Escarpments                                        113
# Sharp reverse curve                                 57
# Tangent road with rolling terrain                   37
# Steep grade upward with mountainous terrain         19
# Name: road_allignment, dtype: int64
# -----------
# Column name: types_of_junction, number of unique values: 8
# Y Shape        5430
# No junction    3837
# Crossing       2177
# Other           445
# Unknown         191
# O Shape         164
# T Shape          60
# X Shape          12
# Name: types_of_junction, dtype: int64
# -----------
# Column name: road_surface_type, number of unique values: 5
# Asphalt roads                       11468
# Earth roads                           358
# Gravel roads                          242
# Other                                 167
# Asphalt roads with some distress       81
# Name: road_surface_type, dtype: int64
# -----------
# Column name: road_surface_conditions, number of unique values: 4
# Dry                     9340
# Wet or damp             2904
# Snow                      70
# Flood over 3cm. deep       2
# Name: road_surface_conditions, dtype: int64
# -----------
# Column name: light_conditions, number of unique values: 4
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: light_conditions, dtype: int64
# -----------
# Column name: weather_conditions, number of unique values: 9
# Normal               10063
# Raining               1331
# Other                  296
# Unknown                292
# Cloudy                 125
# Windy                   98
# Snow                    61
# Raining and Windy       40
# Fog or mist             10
# Name: weather_conditions, dtype: int64
# -----------
# Column name: type_of_collision, number of unique values: 10
# Vehicle with vehicle collision             8929
# Collision with roadside objects            1786
# Collision with pedestrians                  896
# Rollover                                    397
# Collision with animals                      171
# Collision with roadside-parked vehicles      54
# Fall from vehicles                           34
# Other                                        26
# Unknown                                      14
# With Train                                    9
# Name: type_of_collision, dtype: int64
# -----------
# Column name: number_of_vehicles_involved, number of unique values: 6
# 2    8340
# 1    1996
# 3    1568
# 4     363
# 6      42
# 7       7
# Name: number_of_vehicles_involved, dtype: int64
# -----------
# Column name: number_of_casualties, number of unique values: 8
# 1    8397
# 2    2290
# 3     909
# 4     394
# 5     207
# 6      89
# 7      22
# 8       8
# Name: number_of_casualties, dtype: int64
# -----------
# Column name: vehicle_movement, number of unique values: 13
# Going straight         8466
# Moving Backward         985
# Other                   937
# Reversing               563
# Turnover                489
# Getting off             339
# Entering a junction     193
# Overtaking               96
# Unknown                  88
# Stopping                 61
# U-Turn                   50
# Waiting to go            39
# Parked                   10
# Name: vehicle_movement, dtype: int64
# -----------
# Column name: casualty_class, number of unique values: 4
# Driver or rider    4944
# Unknown            4443
# Pedestrian         1649
# Passenger          1280
# Name: casualty_class, dtype: int64
# -----------
# Column name: sex_of_casualty, number of unique values: 3
# Male       5253
# Unknown    4443
# Female     2620
# Name: sex_of_casualty, dtype: int64
# -----------
# Column name: age_band_of_casualty, number of unique values: 6
# Unknown     4443
# 18-30       3145
# 31-50       2455
# Under 18    1035
# Over 51      994
# 5            244
# Name: age_band_of_casualty, dtype: int64
# -----------
# Column name: casualty_severity, number of unique values: 4
# 3    7076
# 0    4443
# 2     771
# 1      26
# Name: casualty_severity, dtype: int64
# -----------
# Column name: work_of_casualty, number of unique values: 7
# Driver           5903
# Unknown          3217
# Self-employed    2044
# Employee          553
# Other             463
# Student           103
# Unemployed         33
# Name: work_of_casualty, dtype: int64
# -----------
# Column name: fitness_of_casualty, number of unique values: 5
# Normal          9608
# Other           2653
# NormalNormal      19
# Deaf              18
# Blind             18
# Name: fitness_of_casualty, dtype: int64
# -----------
# Column name: pedestrian_movement, number of unique values: 9
# Not a Pedestrian                                                                                                                         11390
# Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle                                                              337
# Unknown or other                                                                                                                           293
# Crossing from driver's nearside                                                                                                            140
# Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle                                                               72
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)                                                              46
# Walking along in carriageway, back to traffic                                                                                               18
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle       13
# Walking along in carriageway, facing traffic                                                                                                 7
# Name: pedestrian_movement, dtype: int64
# -----------
# Column name: cause_of_accident, number of unique values: 20
# No distancing                           2263
# Changing lane to the right              1808
# Changing lane to the left               1473
# Driving carelessly                      1402
# No priority to vehicle                  1207
# Moving Backward                         1137
# No priority to pedestrian                721
# Other                                    456
# Overtaking                               430
# Driving under the influence of drugs     340
# Driving to the left                      284
# Getting off the vehicle improperly       197
# Driving at high speed                    174
# Overturning                              149
# Turnover                                  78
# Overspeed                                 61
# Overloading                               59
# Drunk driving                             27
# Unknown                                   25
# Improper parking                          25
# Name: cause_of_accident, dtype: int64
# -----------
# Column name: accident_severity, number of unique values: 3
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: accident_severity, dtype: int64
# -----------

# %% [markdown]
# Changing time to datetime format (there is a problem - if we want to show only time, it'll be a **object** dtype, which isn't great, so i converted to datetime).

# %%
df.time = pd.to_datetime(df.time, format='%H:%M:%S').dt.floor('30T')

# %% [markdown]
# ### Redusing categories
# In this section, i'd like to reduce the number of catergories, because in some there are a small amount of entries, so to make one bigger category from a number of small ones may be beneficial. You may want to stay it as it was before or change by other way. Also, pleace make something in cells with IMPORTANT comment because they seem to me more technical (and i know almost nothing about driving and similar stuff).

# %%
df.educational_level.value_counts()
# Out:
# Junior high school    8360
# Elementary school     2163
# High school           1110
# Above high school      362
# Writing & reading      176
# Unknown                100
# Illiterate              45
# Name: educational_level, dtype: int64

# %%
df.educational_level = df.educational_level.replace(['Writing & reading', 'Unknown', 'Illiterate'], 'Other')
df.educational_level.value_counts()
# Out:
# Junior high school    8360
# Elementary school     2163
# High school           1110
# Above high school      362
# Other                  321
# Name: educational_level, dtype: int64

# %%
df.vehicle_driver_relation.value_counts()
# Out:
# Employee    10206
# Owner        1973
# Other         123
# Unknown        14
# Name: vehicle_driver_relation, dtype: int64

# %%
df.vehicle_driver_relation = df.vehicle_driver_relation.replace(['Unknown'], 'Other')
df.vehicle_driver_relation.value_counts()
# Out:
# Employee    10206
# Owner        1973
# Other         137
# Name: vehicle_driver_relation, dtype: int64

# %%
df.driving_experience.value_counts()
# Out:
# 5-10yr        4192
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# No Licence     118
# unknown         33
# Name: driving_experience, dtype: int64

# %%
df.driving_experience = df.driving_experience.replace(['No Licence', 'unknown'], 'Other')
df.driving_experience.value_counts()
# Out:
# 5-10yr        4192
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# Other          151
# Name: driving_experience, dtype: int64

# %%
### IMPORTANT: i'm not an auto guy at all, so if know what these names mean reduce them accordignly
df.type_of_vehicle.value_counts()
# Out:
# Automobile              4155
# Lorry (41?100Q)         2186
# Other                   1208
# Pick up upto 10Q         811
# Public (12 seats)        711
# Stationwagen             687
# Lorry (11?40Q)           541
# Public (13?45 seats)     532
# Public (> 45 seats)      404
# Long lorry               383
# Taxi                     265
# Motorcycle               177
# Special vehicle           84
# Ridden horse              76
# Turbo                     46
# Bajaj                     29
# Bicycle                   21
# Name: type_of_vehicle, dtype: int64

# %%
df.type_of_vehicle = df.type_of_vehicle.replace(['Special vehicle', 'Ridden horse', 'Turbo', 'Bajaj', 'Bicycle'], 'Other')
df.type_of_vehicle.value_counts()
# Out:
# Automobile              4155
# Lorry (41?100Q)         2186
# Other                   1464
# Pick up upto 10Q         811
# Public (12 seats)        711
# Stationwagen             687
# Lorry (11?40Q)           541
# Public (13?45 seats)     532
# Public (> 45 seats)      404
# Long lorry               383
# Taxi                     265
# Motorcycle               177
# Name: type_of_vehicle, dtype: int64

# %%
df.type_of_vehicle = df.type_of_vehicle.replace(['Public (12 seats)', 'Public (13?45 seats)', 'Public (> 45 seats)'], 'Public')
df.type_of_vehicle.value_counts()
# Out:
# Automobile          4155
# Lorry (41?100Q)     2186
# Public              1647
# Other               1464
# Pick up upto 10Q     811
# Stationwagen         687
# Lorry (11?40Q)       541
# Long lorry           383
# Taxi                 265
# Motorcycle           177
# Name: type_of_vehicle, dtype: int64

# %%
df.type_of_vehicle = df.type_of_vehicle.replace(['Lorry (41?100Q)', 'Lorry (11?40Q)', 'Long lorry'], 'Lorry')
df.type_of_vehicle.value_counts()
# Out:
# Automobile          4155
# Lorry               3110
# Public              1647
# Other               1464
# Pick up upto 10Q     811
# Stationwagen         687
# Taxi                 265
# Motorcycle           177
# Name: type_of_vehicle, dtype: int64

# %%
# I guess it should be 1, not -1
df.defect_of_vehicle.value_counts()
# Out:
# 0    12204
# 7       76
# 5       36
# Name: defect_of_vehicle, dtype: int64

# %%
df.defect_of_vehicle = df.defect_of_vehicle.replace([-1], 1)
df.defect_of_vehicle.value_counts()
# Out:
# 0    12204
# 7       76
# 5       36
# Name: defect_of_vehicle, dtype: int64

# %%
df.area_accident_occured.value_counts()
# Out:
# Other                              4058
# Office areas                       3451
# Residential areas                  2060
#  Church areas                      1060
#  Industrial areas                   456
# School areas                        415
#   Recreational areas                327
#  Outside rural areas                218
#  Hospital areas                     121
#   Market areas                       63
# Rural village areas                  44
# Unknown                              22
# Rural village areasOffice areas      20
# Recreational areas                    1
# Name: area_accident_occured, dtype: int64

# %%
# Also used .strip() to remove whitespaces
df.area_accident_occured = df.area_accident_occured.replace(['Recreational areas', 'Rural village areasOffice areas', 'Unknown', 'Rural village areas', ], 'Other').str.strip()
df.area_accident_occured.value_counts()
# Out:
# Other                  4145
# Office areas           3451
# Residential areas      2060
# Church areas           1060
# Industrial areas        456
# School areas            415
# Recreational areas      327
# Outside rural areas     218
# Hospital areas          121
# Market areas             63
# Name: area_accident_occured, dtype: int64

# %%
df.lanes_or_medians.value_counts()
# Out:
# Two-way (divided with broken lines road marking)    4796
# Undivided Two way                                   3796
# other                                               1660
# Double carriageway (median)                         1020
# One way                                              845
# Two-way (divided with solid lines road marking)      142
# Unknown                                               57
# Name: lanes_or_medians, dtype: int64

# %%
df.lanes_or_medians = df.lanes_or_medians.replace(['other', 'Unknown'], 'Other')
df.lanes_or_medians.value_counts()
# Out:
# Two-way (divided with broken lines road marking)    4796
# Undivided Two way                                   3796
# Other                                               1717
# Double carriageway (median)                         1020
# One way                                              845
# Two-way (divided with solid lines road marking)      142
# Name: lanes_or_medians, dtype: int64

# %%
df.road_allignment.value_counts()
# Out:
# Tangent road with flat terrain                   10601
# Tangent road with mild grade and flat terrain      501
# Steep grade downward with mountainous terrain      429
# Tangent road with mountainous terrain and          396
# Gentle horizontal curve                            163
# Escarpments                                        113
# Sharp reverse curve                                 57
# Tangent road with rolling terrain                   37
# Steep grade upward with mountainous terrain         19
# Name: road_allignment, dtype: int64

# %%
df.road_allignment = df.road_allignment.replace(['Steep grade upward with mountainous terrain', 'Tangent road with rolling terrain'], 'Other')
df.road_allignment.value_counts()
# Out:
# Tangent road with flat terrain                   10601
# Tangent road with mild grade and flat terrain      501
# Steep grade downward with mountainous terrain      429
# Tangent road with mountainous terrain and          396
# Gentle horizontal curve                            163
# Escarpments                                        113
# Sharp reverse curve                                 57
# Other                                               56
# Name: road_allignment, dtype: int64

# %%
df.types_of_junction.value_counts()
# Out:
# Y Shape        5430
# No junction    3837
# Crossing       2177
# Other           445
# Unknown         191
# O Shape         164
# T Shape          60
# X Shape          12
# Name: types_of_junction, dtype: int64

# %%
df.types_of_junction = df.types_of_junction.replace(['X Shape', 'Unknown'], 'Other')
df.types_of_junction.value_counts()
# Out:
# Y Shape        5430
# No junction    3837
# Crossing       2177
# Other           648
# O Shape         164
# T Shape          60
# Name: types_of_junction, dtype: int64

# %%
df.road_surface_type.value_counts()
# Out:
# Asphalt roads                       11468
# Earth roads                           358
# Gravel roads                          242
# Other                                 167
# Asphalt roads with some distress       81
# Name: road_surface_type, dtype: int64

# %%
df.road_surface_type = df.road_surface_type.replace(['Asphalt roads with some distress'], 'Asphalt roads')
df.road_surface_type.value_counts()
# Out:
# Asphalt roads    11549
# Earth roads        358
# Gravel roads       242
# Other              167
# Name: road_surface_type, dtype: int64

# %%
df.road_surface_conditions.value_counts()
# Out:
# Dry                     9340
# Wet or damp             2904
# Snow                      70
# Flood over 3cm. deep       2
# Name: road_surface_conditions, dtype: int64

# %%
df.road_surface_conditions = df.road_surface_conditions.replace(['Flood over 3cm. deep'], 'Wet or damp')
df.road_surface_conditions.value_counts()
# Out:
# Dry            9340
# Wet or damp    2906
# Snow             70
# Name: road_surface_conditions, dtype: int64

# %%
df.light_conditions.value_counts()
# Out:
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: light_conditions, dtype: int64

# %%
df.light_conditions = df.light_conditions.replace(['Darkness - lights unlit'], 'Darkness - no lighting')
df.light_conditions.value_counts()
# Out:
# Daylight                  8798
# Darkness - lights lit     3286
# Darkness - no lighting     232
# Name: light_conditions, dtype: int64

# %%
df.weather_conditions.value_counts()
# Out:
# Normal               10063
# Raining               1331
# Other                  296
# Unknown                292
# Cloudy                 125
# Windy                   98
# Snow                    61
# Raining and Windy       40
# Fog or mist             10
# Name: weather_conditions, dtype: int64

# %%
df.weather_conditions = df.weather_conditions.replace(['Unknown', 'Raining and Windy', 'Fog or mist'], 'Other')
df.weather_conditions.value_counts()
# Out:
# Normal     10063
# Raining     1331
# Other        638
# Cloudy       125
# Windy         98
# Snow          61
# Name: weather_conditions, dtype: int64

# %%
df.type_of_collision.value_counts()
# Out:
# Vehicle with vehicle collision             8929
# Collision with roadside objects            1786
# Collision with pedestrians                  896
# Rollover                                    397
# Collision with animals                      171
# Collision with roadside-parked vehicles      54
# Fall from vehicles                           34
# Other                                        26
# Unknown                                      14
# With Train                                    9
# Name: type_of_collision, dtype: int64

# %%
df.type_of_collision = df.type_of_collision.replace(['Unknown', 'With Train', 'Fall from vehicles'], 'Other')
df.type_of_collision = df.type_of_collision.replace(['Collision with roadside-parked vehicles'], 'Vehicle with vehicle collision')
df.type_of_collision.value_counts()
# Out:
# Vehicle with vehicle collision     8983
# Collision with roadside objects    1786
# Collision with pedestrians          896
# Rollover                            397
# Collision with animals              171
# Other                                83
# Name: type_of_collision, dtype: int64

# %%
### IMPORTANT: who know stuff - try to reduce
df.vehicle_movement.value_counts()
# Out:
# Going straight         8466
# Moving Backward         985
# Other                   937
# Reversing               563
# Turnover                489
# Getting off             339
# Entering a junction     193
# Overtaking               96
# Unknown                  88
# Stopping                 61
# U-Turn                   50
# Waiting to go            39
# Parked                   10
# Name: vehicle_movement, dtype: int64

# %%
df.age_band_of_casualty.value_counts()
# Out:
# Unknown     4443
# 18-30       3145
# 31-50       2455
# Under 18    1035
# Over 51      994
# 5            244
# Name: age_band_of_casualty, dtype: int64

# %%
df.age_band_of_casualty = df.age_band_of_casualty.replace(['5'], 'Unknown')
df.age_band_of_casualty.value_counts()
# Out:
# Unknown     4687
# 18-30       3145
# 31-50       2455
# Under 18    1035
# Over 51      994
# Name: age_band_of_casualty, dtype: int64

# %%
df.work_of_casualty.value_counts()
# Out:
# Driver           5903
# Unknown          3217
# Self-employed    2044
# Employee          553
# Other             463
# Student           103
# Unemployed         33
# Name: work_of_casualty, dtype: int64

# %%
df.work_of_casualty = df.work_of_casualty.replace(['Unemployed', 'Unknown'], 'Other')
df.work_of_casualty.value_counts()
# Out:
# Driver           5903
# Other            3713
# Self-employed    2044
# Employee          553
# Student           103
# Name: work_of_casualty, dtype: int64

# %%
df.fitness_of_casualty.value_counts()
# Out:
# Normal          9608
# Other           2653
# NormalNormal      19
# Deaf              18
# Blind             18
# Name: fitness_of_casualty, dtype: int64

# %%
df.fitness_of_casualty = df.fitness_of_casualty.replace(['Blind', 'Deaf'], 'Other')
df.fitness_of_casualty = df.fitness_of_casualty.replace(['NormalNormal'], 'Normal')
df.fitness_of_casualty.value_counts()
# Out:
# Normal    9627
# Other     2689
# Name: fitness_of_casualty, dtype: int64

# %%
df.pedestrian_movement.value_counts()
# Out:
# Not a Pedestrian                                                                                                                         11390
# Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle                                                              337
# Unknown or other                                                                                                                           293
# Crossing from driver's nearside                                                                                                            140
# Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle                                                               72
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)                                                              46
# Walking along in carriageway, back to traffic                                                                                               18
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle       13
# Walking along in carriageway, facing traffic                                                                                                 7
# Name: pedestrian_movement, dtype: int64

# %%
df.pedestrian_movement = df.pedestrian_movement.replace(['In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle'], 'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)')
df.pedestrian_movement = df.pedestrian_movement.replace(['Walking along in carriageway, back to traffic', 'Walking along in carriageway, facing traffic'], 'Walking along in carriageway')

# %%
df.pedestrian_movement.value_counts()
# Out:
# Not a Pedestrian                                                                  11390
# Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle       337
# Unknown or other                                                                    293
# Crossing from driver's nearside                                                     140
# Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle        72
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)       59
# Walking along in carriageway                                                         25
# Name: pedestrian_movement, dtype: int64

# %%
df.cause_of_accident.value_counts()
# Out:
# No distancing                           2263
# Changing lane to the right              1808
# Changing lane to the left               1473
# Driving carelessly                      1402
# No priority to vehicle                  1207
# Moving Backward                         1137
# No priority to pedestrian                721
# Other                                    456
# Overtaking                               430
# Driving under the influence of drugs     340
# Driving to the left                      284
# Getting off the vehicle improperly       197
# Driving at high speed                    174
# Overturning                              149
# Turnover                                  78
# Overspeed                                 61
# Overloading                               59
# Drunk driving                             27
# Unknown                                   25
# Improper parking                          25
# Name: cause_of_accident, dtype: int64

# %%
df.cause_of_accident = df.cause_of_accident.replace(['Turnover', 'Overspeed', 'Overloading', 'Drunk driving', 'Unknown', 'Improper parking'], 'Other')
df.cause_of_accident.value_counts()
# Out:
# No distancing                           2263
# Changing lane to the right              1808
# Changing lane to the left               1473
# Driving carelessly                      1402
# No priority to vehicle                  1207
# Moving Backward                         1137
# Other                                    731
# No priority to pedestrian                721
# Overtaking                               430
# Driving under the influence of drugs     340
# Driving to the left                      284
# Getting off the vehicle improperly       197
# Driving at high speed                    174
# Overturning                              149
# Name: cause_of_accident, dtype: int64

# %% [markdown]
# ### Correlations
# Well, i'm not totally sure how Phik works, but it should help us to find meaningfult insights.

# %%
phik_matrix = df.phik_matrix()
# Out:
# interval columns not set, guessing: ['defect_of_vehicle', 'number_of_vehicles_involved', 'number_of_casualties', 'casualty_severity']

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(phik_matrix, annot=True, fmt=".2f", annot_kws={"size": 8}, cmap="coolwarm")
plt.title("Phik Matrix")
# Out:
# Text(0.5, 1.0, 'Phik Matrix')

# %% [markdown]
# ### Visualisations (add some plots)

# %%
df.columns
# Out:
# Index(['time', 'day_of_week', 'age_band_of_driver', 'sex_of_driver',
#        'educational_level', 'vehicle_driver_relation', 'driving_experience',
#        'type_of_vehicle', 'owner_of_vehicle', 'service_year_of_vehicle',
#        'defect_of_vehicle', 'area_accident_occured', 'lanes_or_medians',
#        'road_allignment', 'types_of_junction', 'road_surface_type',
#        'road_surface_conditions', 'light_conditions', 'weather_conditions',
#        'type_of_collision', 'number_of_vehicles_involved',
#        'number_of_casualties', 'vehicle_movement', 'casualty_class',
#        'sex_of_casualty', 'age_band_of_casualty', 'casualty_severity',
#        'work_of_casualty', 'fitness_of_casualty', 'pedestrian_movement',
#        'cause_of_accident', 'accident_severity'],
#       dtype='object')

# %%
grouped_time = df.groupby('time').size().reset_index(name='count')
px.line(grouped_time, x='time', y='count', title = 'Number of entries per time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e5fbc3ad-d409-4f1b-9183-300a2ee13135" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5fbc3ad-d409-4f1b-9183-300a2ee13135")) {                    Plotly.newPlot(                        "e5fbc3ad-d409-4f1b-9183-300a2ee13135",                        [{"hovertemplate":"time=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1900-01-01T00:00:00","1900-01-01T00:30:00","1900-01-01T01:00:00","1900-01-01T01:30:00","1900-01-01T02:00:00","1900-01-01T02:30:00","1900-01-01T03:00:00","1900-01-01T03:30:00","1900-01-01T04:00:00","1900-01-01T04:30:00","1900-01-01T05:00:00","1900-01-01T05:30:00","1900-01-01T06:00:00","1900-01-01T06:30:00","1900-01-01T07:00:00","1900-01-01T07:30:00","1900-01-01T08:00:00","1900-01-01T08:30:00","1900-01-01T09:00:00","1900-01-01T09:30:00","1900-01-01T10:00:00","1900-01-01T10:30:00","1900-01-01T11:00:00","1900-01-01T11:30:00","1900-01-01T12:00:00","1900-01-01T12:30:00","1900-01-01T13:00:00","1900-01-01T13:30:00","1900-01-01T14:00:00","1900-01-01T14:30:00","1900-01-01T15:00:00","1900-01-01T15:30:00","1900-01-01T16:00:00","1900-01-01T16:30:00","1900-01-01T17:00:00","1900-01-01T17:30:00","1900-01-01T18:00:00","1900-01-01T18:30:00","1900-01-01T19:00:00","1900-01-01T19:30:00","1900-01-01T20:00:00","1900-01-01T20:30:00","1900-01-01T21:00:00","1900-01-01T21:30:00","1900-01-01T22:00:00","1900-01-01T22:30:00","1900-01-01T23:00:00","1900-01-01T23:30:00"],"xaxis":"x","y":[132,74,78,56,44,40,45,39,51,40,19,57,111,103,183,349,386,442,304,255,218,282,280,323,342,349,405,367,280,359,397,477,458,463,633,595,446,510,349,359,307,297,218,183,235,167,97,112],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"], ...

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
grouped_time = df.groupby('day_of_week').size().reset_index(name='count')
px.bar(grouped_time, x='day_of_week', y='count', title = 'Number of entries per day of week', category_orders={"day_of_week": day_order})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2648c3f2-f5f0-4978-a6b2-c5d421b68d43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2648c3f2-f5f0-4978-a6b2-c5d421b68d43")) {                    Plotly.newPlot(                        "2648c3f2-f5f0-4978-a6b2-c5d421b68d43",                        [{"alignmentgroup":"True","hovertemplate":"day_of_week=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[2041,1681,1666,1467,1851,1770,1840],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type" ...

# %%
driving_experience_order = ['Below 1yr', '1-2yr', '2-5yr', '5-10yr', 'Above 10yr', 'Other']
grouped_time = df.groupby('driving_experience').size().reset_index(name='count')
px.bar(grouped_time, x='driving_experience', y='count', title = 'Number of count for categories in driving_experience', category_orders={"driving_experience": driving_experience_order})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="66891888-5e70-4bfa-a74b-4998a8420fcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66891888-5e70-4bfa-a74b-4998a8420fcb")) {                    Plotly.newPlot(                        "66891888-5e70-4bfa-a74b-4998a8420fcb",                        [{"alignmentgroup":"True","hovertemplate":"driving_experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["1-2yr","2-5yr","5-10yr","Above 10yr","Below 1yr","Other"],"xaxis":"x","y":[1756,2613,4192,2262,1342,151],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo ...

# %%
vehicle_types = df.type_of_vehicle.values
grouped_time = df.groupby('type_of_vehicle').size().reset_index(name='count')
px.bar(grouped_time, x='type_of_vehicle', y='count', title = 'Number of count for vehicle types', category_orders={"type_of_vehicle": vehicle_types})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fb1224d2-2868-47a0-94d3-57c6d2a6ffe3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb1224d2-2868-47a0-94d3-57c6d2a6ffe3")) {                    Plotly.newPlot(                        "fb1224d2-2868-47a0-94d3-57c6d2a6ffe3",                        [{"alignmentgroup":"True","hovertemplate":"type_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Automobile","Lorry","Motorcycle","Other","Pick up upto 10Q","Public","Stationwagen","Taxi"],"xaxis":"x","y":[4155,3110,177,1464,811,1647,687,265],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"ba ...

# %%
# obj_cols = [col for col in df.columns if df[col].dtypes == 'object']

# %%
# Grouping by both type_of_vehicle and accident_severity and count occurrences
grouped_data = df.groupby(['type_of_vehicle', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='type_of_vehicle', y='count', color='accident_severity', title='Accident Severity by Vehicle Type')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1381b9c8-329f-4d96-9c07-649b1a3630fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1381b9c8-329f-4d96-9c07-649b1a3630fc")) {                    Plotly.newPlot(                        "1381b9c8-329f-4d96-9c07-649b1a3630fc",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003etype_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Automobile","Lorry","Motorcycle","Other","Pick up upto 10Q","Public","Stationwagen","Taxi"],"xaxis":"x","y":[51,37,3,17,15,22,8,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003etype_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Automobile","Lorry","Motorcycle","Other","Pick up upto 10Q","Public","Stationwagen","Taxi"],"xaxis":"x","y":[588,446,29,178,132,234,99,37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003etype_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Automobile","Lorry","Motorcycle","Other","Pick up upto 10Q","Public","Stationwagen","Taxi"],"xaxis":"x","y":[3516,2627,145,1269,664,1391,580,223],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111 ...

# %%
# Grouping by both day_of_week and accident_severity and count occurrences
grouped_data = df.groupby(['day_of_week', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='day_of_week', y='count', color='accident_severity', title='Accident Severity by Days in a Week')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2a6f1fc4-1d40-473b-95e1-0ff9b5bc6bc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a6f1fc4-1d40-473b-95e1-0ff9b5bc6bc7")) {                    Plotly.newPlot(                        "2a6f1fc4-1d40-473b-95e1-0ff9b5bc6bc7",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eday_of_week=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[16,12,37,35,22,17,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eday_of_week=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[313,204,245,190,272,257,262],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eday_of_week=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[1712,1465,1384,1242,1557,1496,1559],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"], ...

# %%
# Grouping by both age_band_of_driver and accident_severity and count occurrences
grouped_data = df.groupby(['age_band_of_driver', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='age_band_of_driver', y='count', color='accident_severity', title='Accident Severity by Age Bands of Drivers')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7e7c8374-5d2a-49eb-86b3-4d7fa9dbf67f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e7c8374-5d2a-49eb-86b3-4d7fa9dbf67f")) {                    Plotly.newPlot(                        "7e7c8374-5d2a-49eb-86b3-4d7fa9dbf67f",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eage_band_of_driver=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["18-30","31-50","Over 51","Under 18","Unknown"],"xaxis":"x","y":[62,54,24,12,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eage_band_of_driver=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["18-30","31-50","Over 51","Under 18","Unknown"],"xaxis":"x","y":[604,541,257,169,172],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eage_band_of_driver=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["18-30","31-50","Over 51","Under 18","Unknown"],"xaxis":"x","y":[3605,3492,1304,644,1370],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...

# %%
# Grouping by both sex_of_driver and accident_severity and count occurrences
grouped_data = df.groupby(['sex_of_driver', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='sex_of_driver', y='count', color='accident_severity', title='Accident Severity by Sex of Drivers')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e13fde88-5347-49f0-8224-559e298b2d5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e13fde88-5347-49f0-8224-559e298b2d5a")) {                    Plotly.newPlot(                        "e13fde88-5347-49f0-8224-559e298b2d5a",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003esex_of_driver=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Unknown"],"xaxis":"x","y":[5,152,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003esex_of_driver=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Unknown"],"xaxis":"x","y":[104,1621,18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003esex_of_driver=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Unknown"],"xaxis":"x","y":[592,9664,159],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surfa ...

# %%
# Grouping by both educational_level and accident_severity and count occurrences
grouped_data = df.groupby(['educational_level', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='educational_level', y='count', color='accident_severity', title='Accident Severity by Educational Levels')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a95fde68-8dcb-4bed-8449-f1e53e33e4f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a95fde68-8dcb-4bed-8449-f1e53e33e4f1")) {                    Plotly.newPlot(                        "a95fde68-8dcb-4bed-8449-f1e53e33e4f1",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eeducational_level=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Above high school","Elementary school","High school","Junior high school","Other"],"xaxis":"x","y":[5,24,15,111,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eeducational_level=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Above high school","Elementary school","High school","Junior high school","Other"],"xaxis":"x","y":[53,314,146,1182,48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eeducational_level=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Above high school","Elementary school","High school","Junior high school","Other"],"xaxis":"x","y":[304,1825,949,7067,270],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333 ...

# %%
# Grouping by both vehicle_driver_relation and accident_severity and count occurrences
grouped_data = df.groupby(['vehicle_driver_relation', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='vehicle_driver_relation', y='count', color='accident_severity', title='Accident Severity by Vehicle Driver Relation')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e45d82cf-c279-462a-a8cd-ef89debc92e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e45d82cf-c279-462a-a8cd-ef89debc92e1")) {                    Plotly.newPlot(                        "e45d82cf-c279-462a-a8cd-ef89debc92e1",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003evehicle_driver_relation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Employee","Other","Owner"],"xaxis":"x","y":[123,1,34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003evehicle_driver_relation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Employee","Other","Owner"],"xaxis":"x","y":[1441,15,287],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003evehicle_driver_relation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Employee","Other","Owner"],"xaxis":"x","y":[8642,121,1652],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...

# %%
# Grouping by both driving_experience and accident_severity and count occurrences
grouped_data = df.groupby(['driving_experience', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='driving_experience', y='count', color='accident_severity', title='Accident Severity by Driving Experience')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fda7fe43-5e37-4c99-b4b8-013fa3b59376" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fda7fe43-5e37-4c99-b4b8-013fa3b59376")) {                    Plotly.newPlot(                        "fda7fe43-5e37-4c99-b4b8-013fa3b59376",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003edriving_experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1-2yr","2-5yr","5-10yr","Above 10yr","Below 1yr","Other"],"xaxis":"x","y":[21,46,54,29,7,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003edriving_experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1-2yr","2-5yr","5-10yr","Above 10yr","Below 1yr","Other"],"xaxis":"x","y":[228,381,585,323,207,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003edriving_experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1-2yr","2-5yr","5-10yr","Above 10yr","Below 1yr","Other"],"xaxis":"x","y":[1507,2186,3553,1910,1128,131],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0. ...

# %%
# Grouping by both owner_of_vehicle and accident_severity and count occurrences
grouped_data = df.groupby(['owner_of_vehicle', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='owner_of_vehicle', y='count', color='accident_severity', title='Accident Severity by Vehicle Owner')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0fb88853-25d0-4d3a-946d-11186db99ec9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fb88853-25d0-4d3a-946d-11186db99ec9")) {                    Plotly.newPlot(                        "0fb88853-25d0-4d3a-946d-11186db99ec9",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eowner_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Governmental","Organization","Owner"],"xaxis":"x","y":[16,4,138],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eowner_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Governmental","Organization","Other","Owner"],"xaxis":"x","y":[131,38,1,1573],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eowner_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Governmental","Organization","Other","Owner"],"xaxis":"x","y":[894,270,21,9230],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...

# %%
# Grouping by both service_year_of_vehicle and accident_severity and count occurrences
grouped_data = df.groupby(['service_year_of_vehicle', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='service_year_of_vehicle', y='count', color='accident_severity', title='Accident Severity by Service Year of Vehicle')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="13c45adf-b80b-4a0c-9bd6-447468cbea1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13c45adf-b80b-4a0c-9bd6-447468cbea1e")) {                    Plotly.newPlot(                        "13c45adf-b80b-4a0c-9bd6-447468cbea1e",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eservice_year_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1-2yr","2-5yrs","5-10yrs","Above 10yr","Below 1yr","Unknown"],"xaxis":"x","y":[9,28,16,12,6,87],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eservice_year_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1-2yr","2-5yrs","5-10yrs","Above 10yr","Below 1yr","Unknown"],"xaxis":"x","y":[111,253,191,186,43,959],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eservice_year_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1-2yr","2-5yrs","5-10yrs","Above 10yr","Below 1yr","Unknown"],"xaxis":"x","y":[707,1511,1073,1126,233,5765],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %%
# Grouping by both defect_of_vehicle and accident_severity and count occurrences
grouped_data = df.groupby(['defect_of_vehicle', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='defect_of_vehicle', y='count', color='accident_severity', title='Accident Severity by Defect of Vehicle')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="db5ae1c8-f5b4-41e4-8f05-f8d7f619a802" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db5ae1c8-f5b4-41e4-8f05-f8d7f619a802")) {                    Plotly.newPlot(                        "db5ae1c8-f5b4-41e4-8f05-f8d7f619a802",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003edefect_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":[0],"xaxis":"x","y":[158],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003edefect_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":[0,5,7],"xaxis":"x","y":[1723,6,14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003edefect_of_vehicle=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":[0,5,7],"xaxis":"x","y":[10323,30,62],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks" ...

# %%
# Grouping by both area_accident_occured and accident_severity and count occurrences
grouped_data = df.groupby(['area_accident_occured', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='area_accident_occured', y='count', color='accident_severity', title='Accident Severity by Area Accident Occured')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df91dadf-e39e-4d04-962b-5712580013d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df91dadf-e39e-4d04-962b-5712580013d8")) {                    Plotly.newPlot(                        "df91dadf-e39e-4d04-962b-5712580013d8",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003earea_accident_occured=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Church areas","Industrial areas","Market areas","Office areas","Other","Outside rural areas","Recreational areas","Residential areas","School areas"],"xaxis":"x","y":[10,6,3,39,49,1,8,37,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003earea_accident_occured=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Church areas","Hospital areas","Industrial areas","Market areas","Office areas","Other","Outside rural areas","Recreational areas","Residential areas","School areas"],"xaxis":"x","y":[141,12,60,7,475,591,40,39,324,54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003earea_accident_occured=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Church areas","Hospital areas","Industrial areas","Market areas","Office areas","Other","Outside rural areas","Recreational areas","Residential areas","School areas"],"xaxis":"x","y":[909,109,390,53,2937,3505,177,280,1699,356],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
# Grouping by both lanes_or_medians and accident_severity and count occurrences
grouped_data = df.groupby(['lanes_or_medians', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='lanes_or_medians', y='count', color='accident_severity', title='Accident Severity by Lanes or Medians')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6800c22b-5f61-42f8-9d16-94f7e6842bd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6800c22b-5f61-42f8-9d16-94f7e6842bd2")) {                    Plotly.newPlot(                        "6800c22b-5f61-42f8-9d16-94f7e6842bd2",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003elanes_or_medians=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Double carriageway (median)","One way","Other","Two-way (divided with broken lines road marking)","Two-way (divided with solid lines road marking)","Undivided Two way"],"xaxis":"x","y":[7,12,22,54,1,62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003elanes_or_medians=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Double carriageway (median)","One way","Other","Two-way (divided with broken lines road marking)","Two-way (divided with solid lines road marking)","Undivided Two way"],"xaxis":"x","y":[132,114,248,704,21,524],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003elanes_or_medians=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Double carriageway (median)","One way","Other","Two-way (divided with broken lines road marking)","Two-way (divided with solid lines road marking)","Undivided Two way"],"xaxis":"x","y":[881,719,1447,4038,120,3210],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %%
# Grouping by both road_allignment and accident_severity and count occurrences
grouped_data = df.groupby(['road_allignment', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='road_allignment', y='count', color='accident_severity', title='Accident Severity by Road Allignment')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="85cab9d5-fc3d-40ac-9009-65197d93bd0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85cab9d5-fc3d-40ac-9009-65197d93bd0c")) {                    Plotly.newPlot(                        "85cab9d5-fc3d-40ac-9009-65197d93bd0c",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eroad_allignment=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Escarpments","Gentle horizontal curve","Other","Steep grade downward with mountainous terrain","Tangent road with flat terrain","Tangent road with mild grade and flat terrain","Tangent road with mountainous terrain and"],"xaxis":"x","y":[1,3,2,4,142,2,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eroad_allignment=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Escarpments","Gentle horizontal curve","Other","Sharp reverse curve","Steep grade downward with mountainous terrain","Tangent road with flat terrain","Tangent road with mild grade and flat terrain","Tangent road with mountainous terrain and"],"xaxis":"x","y":[14,20,11,9,63,1488,77,61],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eroad_allignment=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Escarpments","Gentle horizontal curve","Other","Sharp reverse curve","Steep grade downward with mountainous terrain","Tangent road with flat terrain","Tangent road with mild grade and flat terrain","Tangent road with mountainous terrain and"],"xaxis":"x","y":[98,140,43,48,362,8971,422,331],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222, ...

# %%
# Grouping by both types_of_junction and accident_severity and count occurrences
grouped_data = df.groupby(['types_of_junction', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='types_of_junction', y='count', color='accident_severity', title='Accident Severity by Junction Type')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="534f8c7a-a5b2-4c41-b0e9-c3f851504f97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("534f8c7a-a5b2-4c41-b0e9-c3f851504f97")) {                    Plotly.newPlot(                        "534f8c7a-a5b2-4c41-b0e9-c3f851504f97",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003etypes_of_junction=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Crossing","No junction","O Shape","Other","Y Shape"],"xaxis":"x","y":[12,71,1,4,70],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003etypes_of_junction=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Crossing","No junction","O Shape","Other","T Shape","Y Shape"],"xaxis":"x","y":[245,581,26,109,7,775],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003etypes_of_junction=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Crossing","No junction","O Shape","Other","T Shape","Y Shape"],"xaxis":"x","y":[1920,3185,137,535,53,4585],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...

# %%
# Grouping by both road_surface_type and accident_severity and count occurrences
grouped_data = df.groupby(['road_surface_type', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='road_surface_type', y='count', color='accident_severity', title='Accident Severity by Road Surface Type')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="77acc2d4-ab2b-4311-adcc-3e0f25612061" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77acc2d4-ab2b-4311-adcc-3e0f25612061")) {                    Plotly.newPlot(                        "77acc2d4-ab2b-4311-adcc-3e0f25612061",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eroad_surface_type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Asphalt roads","Earth roads","Other"],"xaxis":"x","y":[150,7,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eroad_surface_type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Asphalt roads","Earth roads","Gravel roads","Other"],"xaxis":"x","y":[1623,49,45,26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eroad_surface_type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Asphalt roads","Earth roads","Gravel roads","Other"],"xaxis":"x","y":[9776,302,197,140],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0. ...

# %%
# Grouping by both road_surface_conditions and accident_severity and count occurrences
grouped_data = df.groupby(['road_surface_conditions', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='road_surface_conditions', y='count', color='accident_severity', title='Accident Severity by Road Surface Conditions')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1abd6bbf-1a68-46e9-b7a8-da26f896106c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1abd6bbf-1a68-46e9-b7a8-da26f896106c")) {                    Plotly.newPlot(                        "1abd6bbf-1a68-46e9-b7a8-da26f896106c",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eroad_surface_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Wet or damp"],"xaxis":"x","y":[121,37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eroad_surface_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Snow","Wet or damp"],"xaxis":"x","y":[1332,4,407],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eroad_surface_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Snow","Wet or damp"],"xaxis":"x","y":[7887,66,2462],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[ ...

# %%
# Grouping by both light_conditions and accident_severity and count occurrences
grouped_data = df.groupby(['light_conditions', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='light_conditions', y='count', color='accident_severity', title='Accident Severity by Light Conditions')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2ed61f59-ea62-43c1-a888-bf743a6cc520" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ed61f59-ea62-43c1-a888-bf743a6cc520")) {                    Plotly.newPlot(                        "2ed61f59-ea62-43c1-a888-bf743a6cc520",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003elight_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Darkness - lights lit","Darkness - no lighting","Daylight"],"xaxis":"x","y":[66,5,87],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003elight_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Darkness - lights lit","Darkness - no lighting","Daylight"],"xaxis":"x","y":[465,56,1222],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003elight_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Darkness - lights lit","Darkness - no lighting","Daylight"],"xaxis":"x","y":[2755,171,7489],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666 ...

# %%
# Grouping by both weather_conditions and accident_severity and count occurrences
grouped_data = df.groupby(['weather_conditions', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='weather_conditions', y='count', color='accident_severity', title='Accident Severity by Weather Conditions')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1f6b9135-546f-4915-9bcd-370730661de0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f6b9135-546f-4915-9bcd-370730661de0")) {                    Plotly.newPlot(                        "1f6b9135-546f-4915-9bcd-370730661de0",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eweather_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Cloudy","Normal","Other","Raining","Snow","Windy"],"xaxis":"x","y":[8,1474,82,158,5,16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eweather_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Cloudy","Normal","Other","Raining","Snow","Windy"],"xaxis":"x","y":[117,8454,556,1150,56,82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eweather_conditions=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Normal","Raining"],"xaxis":"x","y":[135,23],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %%
# Grouping by both type_of_collision and accident_severity and count occurrences
grouped_data = df.groupby(['type_of_collision', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='type_of_collision', y='count', color='accident_severity', title='Accident Severity by Collision Type')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f92efcbc-4682-43e2-8e43-1dbfd256594e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f92efcbc-4682-43e2-8e43-1dbfd256594e")) {                    Plotly.newPlot(                        "f92efcbc-4682-43e2-8e43-1dbfd256594e",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003etype_of_collision=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Collision with animals","Collision with pedestrians","Collision with roadside objects","Rollover","Vehicle with vehicle collision"],"xaxis":"x","y":[2,22,24,4,106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003etype_of_collision=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Collision with animals","Collision with pedestrians","Collision with roadside objects","Other","Rollover","Vehicle with vehicle collision"],"xaxis":"x","y":[27,141,272,10,54,1239],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003etype_of_collision=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Collision with animals","Collision with pedestrians","Collision with roadside objects","Other","Rollover","Vehicle with vehicle collision"],"xaxis":"x","y":[142,733,1490,73,339,7638],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}] ...

# %%
# Grouping by both vehicle_movement and accident_severity and count occurrences
grouped_data = df.groupby(['vehicle_movement', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='vehicle_movement', y='count', color='accident_severity', title='Accident Severity by Vehicle Movement')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0b973e18-abbe-42a1-99f1-2e3ae33be7c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b973e18-abbe-42a1-99f1-2e3ae33be7c7")) {                    Plotly.newPlot(                        "0b973e18-abbe-42a1-99f1-2e3ae33be7c7",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003evehicle_movement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Entering a junction","Getting off","Going straight","Moving Backward","Other","Overtaking","Reversing","Stopping","Turnover","Unknown","Waiting to go"],"xaxis":"x","y":[4,5,105,12,10,5,7,1,7,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003evehicle_movement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Entering a junction","Getting off","Going straight","Moving Backward","Other","Overtaking","Parked","Reversing","Stopping","Turnover","U-Turn","Unknown","Waiting to go"],"xaxis":"x","y":[26,44,1191,142,130,8,2,87,10,77,9,13,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003evehicle_movement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Entering a junction","Getting off","Going straight","Moving Backward","Other","Overtaking","Parked","Reversing","Stopping","Turnover","U-Turn","Unknown","Waiting to go"],"xaxis":"x","y":[163,290,7170,831,797,83,8,469,50,405,41,74,34],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888 ...

# %%
# Grouping by both casualty_class and accident_severity and count occurrences
grouped_data = df.groupby(['casualty_class', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='casualty_class', y='count', color='accident_severity', title='Accident Severity by Casualty Class')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="461bab12-b23b-4e86-b03c-123f15c5ae7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("461bab12-b23b-4e86-b03c-123f15c5ae7a")) {                    Plotly.newPlot(                        "461bab12-b23b-4e86-b03c-123f15c5ae7a",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003ecasualty_class=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Driver or rider","Passenger","Pedestrian","Unknown"],"xaxis":"x","y":[71,12,27,48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003ecasualty_class=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Driver or rider","Passenger","Pedestrian","Unknown"],"xaxis":"x","y":[719,182,228,614],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003ecasualty_class=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Driver or rider","Passenger","Pedestrian","Unknown"],"xaxis":"x","y":[4154,1086,1394,3781],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %%
# Grouping by both sex_of_casualty and accident_severity and count occurrences
grouped_data = df.groupby(['sex_of_casualty', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='sex_of_casualty', y='count', color='accident_severity', title='Accident Severity by Sex of Casualty')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0ebbff39-137b-426b-a0e8-4ea9e171a129" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ebbff39-137b-426b-a0e8-4ea9e171a129")) {                    Plotly.newPlot(                        "0ebbff39-137b-426b-a0e8-4ea9e171a129",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003esex_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Unknown"],"xaxis":"x","y":[29,81,48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003esex_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Unknown"],"xaxis":"x","y":[361,768,614],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003esex_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Unknown"],"xaxis":"x","y":[2230,4404,3781],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]] ...

# %%
# Grouping by both age_band_of_casualty and accident_severity and count occurrences
grouped_data = df.groupby(['age_band_of_casualty', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='age_band_of_casualty', y='count', color='accident_severity', title='Accident Severity by Age Band of Casualty')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5bc83b8c-c93e-47b9-98c2-0d9ee90fad90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bc83b8c-c93e-47b9-98c2-0d9ee90fad90")) {                    Plotly.newPlot(                        "5bc83b8c-c93e-47b9-98c2-0d9ee90fad90",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003eage_band_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["18-30","31-50","Over 51","Under 18","Unknown"],"xaxis":"x","y":[51,27,16,13,51],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003eage_band_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["18-30","31-50","Over 51","Under 18","Unknown"],"xaxis":"x","y":[487,349,123,126,658],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003eage_band_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["18-30","31-50","Over 51","Under 18","Unknown"],"xaxis":"x","y":[2607,2079,855,896,3978],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666 ...

# %%
# Grouping by both casualty_severity and accident_severity and count occurrences
grouped_data = df.groupby(['casualty_severity', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='casualty_severity', y='count', color='accident_severity', title='Accident Severity by Casualty Severity')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9ee5fcca-6b59-440c-a2f7-cc835de3dff0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ee5fcca-6b59-440c-a2f7-cc835de3dff0")) {                    Plotly.newPlot(                        "9ee5fcca-6b59-440c-a2f7-cc835de3dff0",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003ecasualty_severity=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":[0,2,3],"xaxis":"x","y":[48,10,100],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003ecasualty_severity=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1,2,3],"xaxis":"x","y":[614,3,98,1028],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003ecasualty_severity=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1,2,3],"xaxis":"x","y":[3781,23,663,5948],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{" ...

# %%
# Grouping by both work_of_casualty and accident_severity and count occurrences
grouped_data = df.groupby(['work_of_casualty', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='work_of_casualty', y='count', color='accident_severity', title='Accident Severity by Work of Casualty')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6fcf4fcc-d7a7-4d5e-a9e2-7474362517a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fcf4fcc-d7a7-4d5e-a9e2-7474362517a3")) {                    Plotly.newPlot(                        "6fcf4fcc-d7a7-4d5e-a9e2-7474362517a3",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003ework_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Driver","Employee","Other","Self-employed"],"xaxis":"x","y":[80,4,47,27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003ework_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Driver","Employee","Other","Self-employed","Student"],"xaxis":"x","y":[824,90,536,274,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003ework_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Driver","Employee","Other","Self-employed","Student"],"xaxis":"x","y":[4999,459,3130,1743,84],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %%
# Grouping by both fitness_of_casualty and accident_severity and count occurrences
grouped_data = df.groupby(['fitness_of_casualty', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='fitness_of_casualty', y='count', color='accident_severity', title='Accident Severity by Fitness of Casualty')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b92849da-f8ac-49ba-9fcc-00bdba434b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b92849da-f8ac-49ba-9fcc-00bdba434b69")) {                    Plotly.newPlot(                        "b92849da-f8ac-49ba-9fcc-00bdba434b69",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003efitness_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Normal","Other"],"xaxis":"x","y":[126,32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003efitness_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Normal","Other"],"xaxis":"x","y":[1365,378],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003efitness_of_casualty=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Normal","Other"],"xaxis":"x","y":[8136,2279],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"su ...

# %%
# Grouping by both pedestrian_movement and accident_severity and count occurrences
grouped_data = df.groupby(['pedestrian_movement', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='pedestrian_movement', y='count', color='accident_severity', title='Accident Severity by Pedestrian Movement')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="652b8d31-6f85-4e39-8664-1a44b1dcb176" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("652b8d31-6f85-4e39-8664-1a44b1dcb176")) {                    Plotly.newPlot(                        "652b8d31-6f85-4e39-8664-1a44b1dcb176",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003epedestrian_movement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Crossing from driver's nearside","Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle","Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle","Not a Pedestrian","Unknown or other"],"xaxis":"x","y":[1,7,1,142,7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003epedestrian_movement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Crossing from driver's nearside","Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle","Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle","In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)","Not a Pedestrian","Unknown or other","Walking along in carriageway"],"xaxis":"x","y":[28,51,10,5,1606,40,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003epedestrian_movement=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Crossing from driver's nearside","Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle","Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle","In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)","Not a Pedestrian","Unknown or other","Walking along in carriageway"],"xaxis":"x","y":[111,279,61,54,9642,246,22],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#f ...

# %%
# Grouping by both cause_of_accident and accident_severity and count occurrences
grouped_data = df.groupby(['cause_of_accident', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='cause_of_accident', y='count', color='accident_severity', title='Accident Severity by Cause of Accident')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7e9fdc8b-f9e3-4d09-8101-c54272ee07f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e9fdc8b-f9e3-4d09-8101-c54272ee07f8")) {                    Plotly.newPlot(                        "7e9fdc8b-f9e3-4d09-8101-c54272ee07f8",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003ecause_of_accident=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Changing lane to the left","Changing lane to the right","Driving at high speed","Driving carelessly","Driving to the left","Driving under the influence of drugs","Getting off the vehicle improperly","Moving Backward","No distancing","No priority to pedestrian","No priority to vehicle","Other","Overtaking","Overturning"],"xaxis":"x","y":[16,23,2,22,4,5,3,26,20,5,13,13,4,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003ecause_of_accident=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Changing lane to the left","Changing lane to the right","Driving at high speed","Driving carelessly","Driving to the left","Driving under the influence of drugs","Getting off the vehicle improperly","Moving Backward","No distancing","No priority to pedestrian","No priority to vehicle","Other","Overtaking","Overturning"],"xaxis":"x","y":[206,260,31,209,53,46,29,162,303,95,149,102,75,23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003ecause_of_accident=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["Changing lane to the left","Changing lane to the right","Driving at high speed","Driving carelessly","Driving to the left","Driving under the influence of drugs","Getting off the vehicle improperly","Moving Backward","No distancing","No priority to pedestrian","No priority to vehicle","Other","Overtaking","Overturning"],"xaxis":"x","y":[1251,1525,141,1171,227,289,165,949,1940,621,1045,616,351,124],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...

# %%
# Grouping by both time and accident_severity and count occurrences
grouped_data = df.groupby(['time', 'accident_severity']).size().reset_index(name='count')

# Creating the bar chart
px.bar(grouped_data, x='time', y='count', color='accident_severity', title='Accident Severity by Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aee7f025-82bc-4cf7-b9e5-0a567db2ae93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aee7f025-82bc-4cf7-b9e5-0a567db2ae93")) {                    Plotly.newPlot(                        "aee7f025-82bc-4cf7-b9e5-0a567db2ae93",                        [{"alignmentgroup":"True","hovertemplate":"accident_severity=Fatal injury\u003cbr\u003etime=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fatal injury","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fatal injury","offsetgroup":"Fatal injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1900-01-01T00:00:00","1900-01-01T01:00:00","1900-01-01T02:30:00","1900-01-01T03:30:00","1900-01-01T04:00:00","1900-01-01T06:30:00","1900-01-01T07:30:00","1900-01-01T08:30:00","1900-01-01T09:00:00","1900-01-01T09:30:00","1900-01-01T11:00:00","1900-01-01T11:30:00","1900-01-01T12:00:00","1900-01-01T13:00:00","1900-01-01T13:30:00","1900-01-01T14:30:00","1900-01-01T15:00:00","1900-01-01T16:00:00","1900-01-01T16:30:00","1900-01-01T17:00:00","1900-01-01T17:30:00","1900-01-01T18:00:00","1900-01-01T18:30:00","1900-01-01T19:30:00","1900-01-01T20:00:00","1900-01-01T20:30:00","1900-01-01T21:00:00","1900-01-01T21:30:00","1900-01-01T22:00:00","1900-01-01T22:30:00","1900-01-01T23:00:00","1900-01-01T23:30:00"],"xaxis":"x","y":[5,4,1,6,1,4,1,2,2,4,8,4,5,6,1,3,8,6,10,11,2,9,7,5,5,9,16,1,2,7,1,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Serious Injury\u003cbr\u003etime=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Serious Injury","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Serious Injury","offsetgroup":"Serious Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1900-01-01T00:00:00","1900-01-01T00:30:00","1900-01-01T01:00:00","1900-01-01T01:30:00","1900-01-01T02:00:00","1900-01-01T02:30:00","1900-01-01T03:00:00","1900-01-01T03:30:00","1900-01-01T04:00:00","1900-01-01T04:30:00","1900-01-01T05:00:00","1900-01-01T05:30:00","1900-01-01T06:00:00","1900-01-01T06:30:00","1900-01-01T07:00:00","1900-01-01T07:30:00","1900-01-01T08:00:00","1900-01-01T08:30:00","1900-01-01T09:00:00","1900-01-01T09:30:00","1900-01-01T10:00:00","1900-01-01T10:30:00","1900-01-01T11:00:00","1900-01-01T11:30:00","1900-01-01T12:00:00","1900-01-01T12:30:00","1900-01-01T13:00:00","1900-01-01T13:30:00","1900-01-01T14:00:00","1900-01-01T14:30:00","1900-01-01T15:00:00","1900-01-01T15:30:00","1900-01-01T16:00:00","1900-01-01T16:30:00","1900-01-01T17:00:00","1900-01-01T17:30:00","1900-01-01T18:00:00","1900-01-01T18:30:00","1900-01-01T19:00:00","1900-01-01T19:30:00","1900-01-01T20:00:00","1900-01-01T20:30:00","1900-01-01T21:00:00","1900-01-01T21:30:00","1900-01-01T22:00:00","1900-01-01T22:30:00","1900-01-01T23:00:00","1900-01-01T23:30:00"],"xaxis":"x","y":[18,20,7,10,9,4,16,6,6,3,2,18,17,15,32,45,56,52,60,18,21,31,37,43,37,51,57,51,37,49,71,71,61,50,87,62,58,74,56,48,60,47,31,14,49,26,22,28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"accident_severity=Slight Injury\u003cbr\u003etime=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slight Injury","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Slight Injury","offsetgroup":"Slight Injury","orientation":"v","showlegend":true,"textposition":"auto","x":["1900-01-01T00:00:00","1900-01-01T00:30:00","1900-01-01T01:00:00","1900-01-01T01:30:00","1900-01-01T02:00:00","1900-01-01T02:30:00","1900-01-01T03:00:00","1900-01-01T03:30:00","1900-01-01T04:00:00","1900-01-01T04:30:00","1900-01-01T05:00:00","1900-01-01T05:30:00","1900-01-01T06:00:00","1900-01-01T06:3 ...
